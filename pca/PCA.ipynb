# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("train.csv")
X_raw_test = pd.read_csv("test.csv")
y_test = pd.read_csv("gender_submission.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
X_raw_train = df.drop('Survived', axis=1)
y_train = df['Survived']

# %%
X_raw_train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    str
#  3   Sex          891 non-null    str
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    str
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    str
#  10  Embarked     889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 111.9 KB

# %% [markdown]
# Encoding

# %%
X_raw_train.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
X_raw_train[['Ticket', 'Cabin', 'Embarked']]
# Out:
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 3 columns]

# %% [markdown]
# Scale

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_raw_train)
X_test = sc.fit_transform(X_raw_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 X_train = sc.fit_transform(X_raw_train)
#       4 X_test = sc.fit_transform(X_raw_test)
#
# File ~/Documents/ITC/ITC/Year3/2nd_semester/Numerical_Analysis/Assigment/NA assignment/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
# ...

# %%
from sklearn.decomposition import PCA
